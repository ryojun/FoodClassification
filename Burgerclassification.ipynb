# %% [markdown]
# <a href="https://colab.research.google.com/github/ryojun/FoodClassification/blob/master/Burgerclassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np
# from scipy.misc import imresize
# from skimage.transform import rescale, resize, downscale_local_mean
from PIL import Image

import os
from os import listdir
from os.path import isfile, join
import shutil
import stat
import collections
from collections import defaultdict

from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

import h5py
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.applications.inception_v3 import preprocess_input
from keras.models import load_model
import cv2

# %%
from __future__ import absolute_import, division, print_function

import tensorflow as tf

import tensorflow.keras.backend as K
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras import regularizers
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.regularizers import l2

from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras.applications.inception_v3 import preprocess_input

import cv2
import os
import random
import collections
from collections import defaultdict

from shutil import copy
from shutil import copytree, rmtree

import numpy as np

import matplotlib.pyplot as plt
import matplotlib.image as img
# %matplotlib inline

# %%
def prepare_data(filepath, src,dest):
  classes_images = defaultdict(list)
  with open(filepath, 'r') as txt:
      paths = [read.strip() for read in txt.readlines()]
      for p in paths:
        food = p.split('/')
        classes_images[food[0]].append(food[1])

  for food in classes_images.keys():
    print("\nCopying images into ",food)
    if not os.path.exists(os.path.join(dest,food)):
      os.makedirs(os.path.join(dest,food))
    for i in classes_images[food]:
      copy(os.path.join(src,food,i), os.path.join(dest,food,i))
  print("Copying Done!")

# %%
root_position = "/content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/"

# %%
import os
all_files = os.listdir(root_position+"foods-IG/sushi/test")
nameList = []
for x in all_files:
  fileIn = os.listdir(root_position+"foods-IG/sushi/test/"+x)
  for i in fileIn:
    nameList.append(x+"/"+i)
print(nameList)
with open(root_position+"foods-IG/meta/test.txt", 'w') as f:
  for item in nameList:
    f.write("%s\n" % item)
# Out:
# ['sushi/14350611_1745139269079269_871702448_n.jpg', 'sushi/14276600_544009492457779_677119291_n.jpg', 'sushi/14280560_642574385924270_455497691_n.jpg', 'sushi/14279127_535772216613459_1726605195_n.jpg', 'sushi/14334715_932588106885151_1159388922_n.jpg', 'sushi/14276674_336750743334438_5436922894401667072_n.jpg', 'sushi/14334301_191047494639132_5078918734416969728_n.jpg', 'sushi/14478458_1596122894023146_360501606157910016_n.jpg', 'sushi/14334728_169702833474087_3222105446374440960_n.jpg', 'sushi/14374252_1845361015696699_7070587956829880320_n.jpg', 'sushi/14359600_141943009597821_4026025678104166400_n.jpg', 'sushi/14533622_542790535928749_3413878566524289024_n.jpg', 'sushi/14504942_1114913061922276_2409802761332850688_n.jpg', 'sushi/14574227_708711179279954_4229519059630161920_n.jpg', 'sushi/14624252_949659311844707_960076498058870784_n.jpg', 'sushi/14592050_744559589028568_4715784824407719936_n.jpg', 'sushi/14474200_658117911014627_9131596003147776000_n.jpg', 'sushi/14693697_1214652278573550_4826701938215092224_n.jpg', 'sushi/14736249_170594623395743_3497310835984826368_n.jpg', 'sushi/14574232_1800615740152173_4839852015678914560_n.jpg', 'sushi/14733699_321764264857584_8105759840640434176_n.jpg', 'sushi/14718104_1222664604460573_8211006523875262464_n.jpg', 'sushi/14716665_638354706343701_3555094424042078208_n.jpg', 'sushi/14717368_1500053320011509_338475575049977856_n.jpg', 'sushi/14677378_543150969211954_5630497882181206016_n.jpg', 'sushi/14717475_331296580572768_8589548521684729856_n.jpg', 'sushi/14727550_1750681305149219_4015762196620378112_n.jpg', 'sushi/15035781_1440672972617008_3713676694058434560_n.jpg', 'sushi/15056545_1602997026673637_1133421008758243328_n.jpg', 'sushi/14449125_653539984819608_2698602718867488768_n.jpg', 'sushi/15043862_314358038949401_8313034829201408000_n.jpg', 'sushi/14134666_157252108077778_4209035690580639744_n.jpg', 'sushi/15048217_221788811578493_3459856307392086016_n.jpg', 'sushi/15046971_653273068180748_2437783532668452864_n.jpg', 'sushi/15035714_1146190475450717_3893835986416697344_n.jpg', 'sushi/15056776_1113721445392853_1522683017305260032_n.jpg', 'sushi/15099424_220624925037974_5289744518470434816_n.jpg', 'sushi/14504684_1799968396912981_8286191154752389120_n.jpg', 'sushi/14716592_352585081767609_3144566013777936384_n.jpg', 'sushi/15259090_909137775853204_8217688264627191808_n.jpg', 'sushi/15048024_706960069469459_7798563138017689600_n.jpg', 'sushi/15258575_1128510410589283_320283364894441472_n.jpg', 'sushi/15275581_422848584770188_2378704122913226752_n.jpg', 'sushi/15337251_1820041714943985_577709784627675136_n.jpg', 'sushi/15306798_1386067904791819_1420062680802131968_n.jpg', 'sushi/15534691_1804672019806537_198071260192702464_n.jpg', 'sushi/15538894_1279036565494844_8643766372058267648_n.jpg', 'sushi/14583535_1979341325626826_5939404321090174976_n.jpg', 'sushi/15337327_120698291757423_5866740269080117248_n.jpg', 'sushi/15338289_216726832069003_2109152026955874304_n.jpg', 'sushi/15534647_1165136283568225_5430481993940860928_n.jpg', 'sushi/15538842_551145431752078_41176293848383488_n.jpg', 'sushi/15624541_196210554175645_4576664477138681856_n.jpg', 'sushi/15625231_307274959667560_6402400021777481728_n.jpg', 'sushi/15534657_260028737749469_7367273534449516544_n.jpg', 'sushi/15625409_1877775212458715_7171066414617329664_n.jpg', 'sushi/15625007_1827825590767297_989701722177798144_n.jpg', 'sushi/15539070_235115480249292_4256177857211924480_n.jpg', 'sushi/15538390_233068937120940_522601256821194752_n.jpg', 'sushi/15535012_1205002099554092_651521099711905792_n.jpg', 'sushi/14540462_128628494303583_234792745242198016_n.jpg', 'sushi/15802149_1764280337231026_7534208235956338688_n.jpg', 'sushi/15875884_928322507304332_8446360784551804928_n.jpg', 'sushi/15802540_1167851716663926_8515301323254530048_n.jpg', 'sushi/15877529_422747448116326_61692192980205568_n.jpg', 'sushi/15877555_923782871090798_4638303275085463552_n.jpg', 'sushi/15803542_376489009398212_3124557466247888896_n.jpg', 'sushi/15876505 ...

# %%
class_to_ix = {}
ix_to_class = {}
with open(root_position+'foods-IG/meta/classes.txt', 'r') as txt:
  classes = [l.strip() for l in txt.readlines()]
  class_to_ix = dict(zip(classes, range(len(classes))))
  ix_to_class = dict(zip(range(len(classes)), classes))
  class_to_ix = {v: k for k, v in ix_to_class.items()}
sorted_class_to_ix = collections.OrderedDict(sorted(class_to_ix.items()))

# Only split files if haven't already
if not os.path.isdir(root_position+'foods-IG/sushi/test') and not os.path.isdir(root_position+'foods-IG/sushi/train'):

    def copytree(src, dst, symlinks = False, ignore = None):
        if not os.path.exists(dst):
            os.makedirs(dst)
            shutil.copystat(src, dst)
        lst = os.listdir(src)
        if ignore:
            excl = ignore(src, lst)
            lst = [x for x in lst if x not in excl]
        for item in lst:
            s = os.path.join(src, item)
            d = os.path.join(dst, item)
            if symlinks and os.path.islink(s):
                if os.path.lexists(d):
                    os.remove(d)
                os.symlink(os.readlink(s), d)
                try:
                    st = os.lstat(s)
                    mode = stat.S_IMODE(st.st_mode)
                    os.lchmod(d, mode)
                except:
                    pass # lchmod not available
            elif os.path.isdir(s):
                copytree(s, d, symlinks, ignore)
            else:
                shutil.copy2(s, d)

    def generate_dir_file_map(path):
        dir_files = defaultdict(list)
        with open(path, 'r') as txt:
            files = [l.strip() for l in txt.readlines()]
            for f in files:
                dir_name, id = f.split('/')
                dir_files[dir_name].append(id)
        return dir_files

    train_dir_files = generate_dir_file_map(root_position+'foods-IG/meta/train.txt')
    test_dir_files = generate_dir_file_map(root_position+'foods-IG/meta/test.txt')


    def ignore_train(d, filenames):
        print(d)
        subdir = d.split('/')[-1]
        to_ignore = train_dir_files[subdir]
        return to_ignore

    def ignore_test(d, filenames):
        print(d)
        subdir = d.split('/')[-1]
        to_ignore = test_dir_files[subdir]
        return to_ignore

    copytree(root_position+'foods-IG/images', root_position+'foods-IG/sushi/test', ignore=ignore_train)
    copytree(root_position+'foods-IG/images', root_position+'foods-IG/sushi/train', ignore=ignore_test)
    
else:
    print('Train/Test files already copied into separate folders.')
# Out:
# Train/Test files already copied into separate folders.

# %%
print("Creating train data...")
prepare_data(root_position+'foods-IG/meta/train.txt', root_position+'foods-IG/images', root_position+'foods-IG/sushi/train')
# Out:
# Creating train data...
# Copying Done!

# %%
# Prepare test data by copying images from food-101/images to food-101/test using the file test.txt
print("Creating test data...")
prepare_data(root_position+'foods-IG/meta/test.txt', root_position+'foods-IG/images', root_position+'foods-IG/sushi/test')
# Out:
# Creating test data...
#
# Copying images into  sushi
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-510b8d865d3c> in <module>()
#       1 # Prepare test data by copying images from food-101/images to food-101/test using the file test.txt
#       2 print("Creating test data...")
# ----> 3 prepare_data(root_position+'foods-IG/meta/test.txt', root_position+'foods-IG/images', root_position+'foods-IG/sushi/test')
#
# <ipython-input-13-2fc9ec6dcffa> in prepare_data(filepath, src, dest)
#      12       os.makedirs(os.path.join(dest,food))
#      13     for i in classes_images[food]:
# ---> 14       copy(os.path.join(src,food,i), os.path.join(dest,food,i))
#      15   print("Copying Done!")
#
# /usr/lib/python3.7/shutil.py in copy(src, dst, follow_symlinks)
#     246     if os.path.isdir(dst):
#     247         dst = os.path.join(dst, os.path.basename(src))
# --> 248     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     249     copymode(src, dst, follow_symlinks=follow_symlinks)
#     250     return dst
#
# /usr/lib/python3.7/shutil.py in copyfile(src, dst, follow_symlinks)
#     118         os.symlink(os.readlink(src), dst)
#     119     else:
# --> 120         with open(src, 'rb') as fsrc:
#     121             with open(dst, 'wb') as fdst:
#     122                 copyfileobj(fsrc, fdst)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/foods-IG/images/sushi/14350611_1745139269079269_871702448_n.jpg'

# %%
def dataset_mini(food_list, src, dest):
  if os.path.exists(dest):
    rmtree(dest) # removing dataset_mini(if it already exists) folders so that we will have only the classes that we want
  os.makedirs(dest)
  for food_item in food_list :
    print("Copying images into",food_item)
    copytree(os.path.join(src,food_item), os.path.join(dest,food_item))

# %%
# picking 3 food items and generating separate data folders for the same
food_list = ['burger','not']
src_train = root_position+'burger/burger/train'
dest_train = root_position+'burger/burger/train_mini'
src_test = root_position+'burger/burger/test'
dest_test = root_position+'burger/burger/test_mini'

# %%
print("Creating train data folder with new classes")
dataset_mini(food_list, src_train, dest_train)
# Out:
# Creating train data folder with new classes
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-a39c79f071c7> in <module>()
#       1 print("Creating train data folder with new classes")
# ----> 2 dataset_mini(food_list, src_train, dest_train)
#
# NameError: name 'dataset_mini' is not defined

# %%
print("Total number of samples in train folder")
train_files = sum([len(files) for i, j, files in os.walk(root_position+"burger/burger/train")])
print(train_files)
# Out:
# Total number of samples in train folder
# 1196

# %%
print("Creating test data folder with new classes")
dataset_mini(food_list, src_test, dest_test)
# Out:
# Creating test data folder with new classes
# Copying images into sushi
# Copying images into not

# %%
print("Total number of samples in test folder")
test_files = sum([len(files) for i, j, files in os.walk(root_position+"burger/burger/test")])
print(test_files)
# Out:
# Total number of samples in test folder
# 599

# %%
# !nvidia-smi
# Out:
# Sat Mar 27 10:08:25 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.56       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
def train_model(n_classes,num_epochs, nb_train_samples,nb_validation_samples):
  K.clear_session()

  img_width, img_height = 299, 299
  train_data_dir = root_position+'burger/burger/train'
  validation_data_dir = root_position+'burger/burger/test'
  batch_size = 16
  bestmodel_path = '/content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/burger/'+'weights-improvement-{epoch:02d}-{val_accuracy:.2f} bestmodel_2class.hdf5'
  trainedmodel_path = '/content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/burger/'+'weights-improvement-{epoch:02d}-{val_accuracy:.2f} trainedmodel_2class.hdf5'
  history_path = '/content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/burger/'+'history_'+str(n_classes)+'.log'

  train_datagen = ImageDataGenerator(
      preprocessing_function=preprocess_input,
      shear_range=0.2,
      zoom_range=0.2,
      horizontal_flip=True)

  test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

  train_generator = train_datagen.flow_from_directory(
      train_data_dir,
      target_size=(img_height, img_width),
      batch_size=batch_size,
      class_mode='categorical')

  validation_generator = test_datagen.flow_from_directory(
      validation_data_dir,
      target_size=(img_height, img_width),
      batch_size=batch_size,
      class_mode='categorical')


  inception = InceptionV3(weights='imagenet', include_top=False)
  x = inception.output
  x = GlobalAveragePooling2D()(x)
  x = Dense(128,activation='relu')(x)
  x = Dropout(0.2)(x)

  predictions = Dense(n_classes,kernel_regularizer=regularizers.l2(0.005), activation='softmax')(x)

  model = Model(inputs=inception.input, outputs=predictions)
  model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])
  checkpoint = ModelCheckpoint(filepath=bestmodel_path, verbose=1, save_best_only=True, monitor='val_accuracy', mode='max')
  csv_logger = CSVLogger(history_path)

  history = model.fit_generator(train_generator,
                      steps_per_epoch = nb_train_samples // batch_size,
                      validation_data=validation_generator,
                      validation_steps=nb_validation_samples // batch_size,
                      epochs=num_epochs,
                      verbose=1,
                      callbacks=[csv_logger, checkpoint])

  model.save(trainedmodel_path)
  class_map = train_generator.class_indices
  return history, class_map

# %%
# Train the model with data from 3 classes
n_classes = 2
epochs = 50
nb_train_samples = train_files
nb_validation_samples = test_files

history, class_map_3 = train_model(n_classes,epochs, nb_train_samples,nb_validation_samples)
print(class_map_3)
# Out:
# Found 1196 images belonging to 2 classes.
# Found 599 images belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 74/74 [==============================] - 1108s 15s/step - loss: 0.7185 - accuracy: 0.5250 - val_loss: 0.5706 - val_accuracy: 0.7568
#
# Epoch 00001: val_accuracy improved from -inf to 0.75676, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/burger/weights-improvement-01-0.76 bestmodel_2class.hdf5
# Epoch 2/50
# 74/74 [==============================] - 31s 420ms/step - loss: 0.5275 - accuracy: 0.8021 - val_loss: 0.3970 - val_accuracy: 0.9240
#
# Epoch 00002: val_accuracy improved from 0.75676 to 0.92399, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/burger/weights-improvement-02-0.92 bestmodel_2class.hdf5
# Epoch 3/50
# 74/74 [==============================] - 32s 428ms/step - loss: 0.3900 - accuracy: 0.8902 - val_loss: 0.3027 - val_accuracy: 0.9595
#
# Epoch 00003: val_accuracy improved from 0.92399 to 0.95946, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/burger/weights-improvement-03-0.96 bestmodel_2class.hdf5
# Epoch 4/50
# 74/74 [==============================] - 31s 420ms/step - loss: 0.3291 - accuracy: 0.9025 - val_loss: 0.2710 - val_accuracy: 0.9578
#
# Epoch 00004: val_accuracy did not improve from 0.95946
# Epoch 5/50
# 74/74 [==============================] - 31s 421ms/step - loss: 0.2837 - accuracy: 0.9113 - val_loss: 0.2229 - val_accuracy: 0.9679
#
# Epoch 00005: val_accuracy improved from 0.95946 to 0.96791, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/burger/weights-improvement-05-0.97 bestmodel_2class.hdf5
# Epoch 6/50
# 74/74 [==============================] - 31s 422ms/step - loss: 0.2594 - accuracy: 0.9167 - val_loss: 0.1951 - val_accuracy: 0.9696
#
# Epoch 00006: val_accuracy improved from 0.96791 to 0.96959, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/burger/weights-improvement-06-0.97 bestmodel_2class.hdf5
# Epoch 7/50
# 74/74 [==============================] - 32s 425ms/step - loss: 0.2042 - accuracy: 0.9486 - val_loss: 0.1553 - val_accuracy: 0.9831
#
# Epoch 00007: val_accuracy improved from 0.96959 to 0.98311, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/burger/weights-improvement-07-0.98 bestmodel_2class.hdf5
# Epoch 8/50
# 74/74 [==============================] - 32s 430ms/step - loss: 0.1626 - accuracy: 0.9529 - val_loss: 0.1437 - val_accuracy: 0.9814
#
# Epoch 00008: val_accuracy did not improve from 0.98311
# Epoch 9/50
# 74/74 [==============================] - 31s 422ms/step - loss: 0.2074 - accuracy: 0.9414 - val_loss: 0.1409 - val_accuracy: 0.9814
#
# Epoch 00009: val_accuracy did not improve from 0.98311
# Epoch 10/50
# 74/74 [==============================] - 31s 420ms/step - loss: 0.1510 - accuracy: 0.9559 - val_loss: 0.1309 - val_accuracy: 0.9831
#
# Epoch 00010: val_accuracy did not improve from 0.98311
# Epoch 11/50
# 74/74 [==============================] - 31s 418ms/step - loss: 0.1475 - accuracy: 0.9527 - val_loss: 0.1181 - val_accuracy: 0.9831
#
# Epoch 00011: val_accuracy did not improve from 0.98311
# Epoch 12/50
# 74/74 [==============================] - 31s 420ms/step - loss: 0.1618 - accuracy: 0.9574 - val_loss: 0.1123 - val_accuracy: 0.9831
#
# Epoch 00012: val_accuracy did not improve from 0.98311
# Epoch 13/50
# 74/74 [==============================] - 31s 421ms/step - loss: 0.1390 - accuracy: 0.9620 - val_loss: 0.1062 - val_accuracy: 0.9831
#
# Epoch 00013: val_accuracy did not improve from 0.98311
# Epoch 14/50
# 74/74 [==============================] - 31s 417ms/step - loss: 0.1087 - accuracy: 0.9784 - val_loss: 0.1023 - val_accuracy: 0.9814
#
# Epoch 00014: val_accuracy did not improve from 0.98311
# Epoch 15/50
# 74/74 [==============================] - 31s 419ms/step - loss: 0.1096 - accuracy: 0.9670 - val_loss: 0.0936 - val_accuracy: 0.9848
#
# Epoch 00015: val_accuracy improved from 0.98311 to 0.98480, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/burger/weights-improvement-15-0.98 bestmodel_2class.hdf5
# Epoch 16/50
# 74/74 [==============================] - 32s 434ms/step - loss: 0.0795 - accuracy: 0.9860 - val_loss: 0.0923 - val_accuracy: 0.9814
#
# Epoch 00016: val_accuracy did not improve from 0.98480
# Epoch 17/50
# 74/74 [==============================] - 32s 436ms/step - loss: 0.1163 - accuracy: 0.9743 - val_loss: 0.0774 - val_accuracy: 0.9882
#
# Epoch 00017: val_accuracy improved from 0.98480 to 0.98818, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/burger/weights-improvement-17-0.99 bestmodel_2class.hdf5
# Epoch 18/50
# 74/74 [==============================] - 33s 441ms/step - loss: 0.1159 - accuracy: 0.9568 - val_loss: 0.0900 - val_accuracy: 0.9797
#
# Epoch 00018: val_accuracy did not improve from 0.98818
# Epoch 19/50
# 74/74 [==============================] - 32s 425ms/step - loss: 0.0930 - accuracy: 0.9759 - val_loss: 0.0747 - val_accuracy: 0.9882
#
# Epoch 00019: val_accuracy did not improve from 0.98818
# Epoch 20/50
# 74/74 [==============================] - 32s 426ms/step - loss: 0.0780 - accuracy: 0.9819 - val_loss: 0.0746 - val_accuracy: 0.9848
#
# Epoch 00020: val_accuracy did not improve from 0.98818
# Epoch 21/50
# 74/74 [==============================] - 32s 427ms/step - loss: 0.0885 - accuracy: 0.9795 - val_loss: 0.0797 - val_accuracy: 0.9831
#
# Epoch 00021: val_accuracy did not improve from 0.98818
# Epoch 22/50
# 74/74 [==============================] - 32s 427ms/step - loss: 0.1109 - accuracy: 0.9682 - val_loss: 0.0686 - val_accuracy: 0.9899
#
# Epoch 00022: val_accuracy improved from 0.98818 to 0.98986, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/burger/weights-improvement-22-0.99 bestmodel_2class.hdf5
# Epoch 23/50
# 74/74 [==============================] - 32s 431ms/step - loss: 0.0676 - accuracy: 0.9871 - val_loss: 0.0650 - val_accuracy: 0.9882
#
# Epoch 00023: val_accuracy did not improve from 0.98986
# Epoch 24/50
# 74/74 [==============================] - 32s 427ms/step - loss: 0.0737 - accuracy: 0.9881 - val_loss: 0.0651 - val_accuracy: 0.9882
#
# Epoch 00024: val_accuracy did not improve from 0.98986
# Epoch 25/50
# 74/74 [==============================] - 32s 425ms/step - loss: 0.0665 - accuracy: 0.9825 - val_loss: 0.0565 - val_accuracy: 0.9916
#
# Epoch 00025: val_accuracy improved from 0.98986 to 0.99155, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/burger/weights-improvement-25-0.99 bestmodel_2class.hdf5
# Epoch 26/50
# 74/74 [==============================] - 32s 434ms/step - loss: 0.0575 - accuracy: 0.9868 - val_loss: 0.0601 - val_accuracy: 0.9899
#
# Epoch 00026: val_accuracy did not improve from 0.99155
# Epoch 27/50
# 74/74 [==============================] - 32s 427ms/step - loss: 0.0904 - accuracy: 0.9744 - val_loss: 0.0521 - val_accuracy: 0.9916
#
# Epoch 00027: val_accuracy did not improve from 0.99155
# Epoch 28/50
# 74/74 [==============================] - 32s 429ms/step - loss: 0.0540 - accuracy: 0.9919 - val_loss: 0.0590 - val_accuracy: 0.9865
#
# Epoch 00028: val_accuracy did not improve from 0.99155
# Epoch 29/50
# 74/74 [==============================] - 31s 425ms/step - loss: 0.0628 - accuracy: 0.9881 - val_loss: 0.0593 - val_accuracy: 0.9865
#
# Epoch 00029: val_accuracy did not improve from 0.99155
# Epoch 30/50
# 74/74 [==============================] - 32s 425ms/step - loss: 0.0656 - accuracy: 0.9912 - val_loss: 0.0697 - val_accuracy: 0.9865
#
# Epoch 00030: val_accuracy did not improve from 0.99155
# Epoch 31/50
# 74/74 [==============================] - 32s 427ms/step - loss: 0.0762 - accuracy: 0.9798 - val_loss: 0.0615 - val_accuracy: 0.9865
#
# Epoch 00031: val_accuracy did not improve from 0.99155
# Epoch 32/50
# 74/74 [==============================] - 31s 425ms/step - loss: 0.0502 - accuracy: 0.9926 - val_loss: 0.0663 - val_accuracy: 0.9848
#
# Epoch 00032: val_accuracy did not improve from 0.99155
# Epoch 33/50
# 74/74 [==============================] - 32s 425ms/step - loss: 0.0644 - accuracy: 0.9861 - val_loss: 0.0568 - val_accuracy: 0.9882
#
# Epoch 00033: val_accuracy did not improve from 0.99155
# Epoch 34/50
# 74/74 [==============================] - 31s 420ms/step - loss: 0.0606 - accuracy: 0.9849 - val_loss: 0.0598 - val_accuracy: 0.9865
#
# Epoch 00034: val_accuracy did not improve from 0.99155
# Epoch 35/50
# 74/74 [==============================] - 31s 424ms/step - loss: 0.0540 - accuracy: 0.9902 - val_loss: 0.0623 - val_accuracy: 0.9865
#
# Epoch 00035: val_accuracy did not improve from 0.99155
# Epoch 36/50
# 74/74 [==============================] - 31s 424ms/step - loss: 0.0625 - accuracy: 0.9854 - val_loss: 0.0570 - val_accuracy: 0.9882
#
# Epoch 00036: val_accuracy did not improve from 0.99155
# Epoch 37/50
# 74/74 [==============================] - 31s 423ms/step - loss: 0.0505 - accuracy: 0.9898 - val_loss: 0.0589 - val_accuracy: 0.9882
#
# Epoch 00037: val_accuracy did not improve from 0.99155
# Epoch 38/50
# 74/74 [==============================] - 32s 432ms/step - loss: 0.0483 - accuracy: 0.9898 - val_loss: 0.0488 - val_accuracy: 0.9916
#
# Epoch 00038: val_accuracy did not improve from 0.99155
# Epoch 39/50
# 74/74 [==============================] - 32s 430ms/step - loss: 0.0363 - accuracy: 0.9964 - val_loss: 0.0573 - val_accuracy: 0.9882
#
# Epoch 00039: val_accuracy did not improve from 0.99155
# Epoch 40/50
# 74/74 [==============================] - 31s 424ms/step - loss: 0.0519 - accuracy: 0.9841 - val_loss: 0.0486 - val_accuracy: 0.9899
#
# Epoch 00040: val_accuracy did not improve from 0.99155
# Epoch 41/50
# 74/74 [==============================] - 32s 428ms/step - loss: 0.0433 - accuracy: 0.9992 - val_loss: 0.0523 - val_accuracy: 0.9882
#
# Epoch 00041: val_accuracy did not improve from 0.99155
# Epoch 42/50
# 74/74 [==============================] - 32s 427ms/step - loss: 0.0471 - accuracy: 0.9943 - val_loss: 0.0516 - val_accuracy: 0.9882
#
# Epoch 00042: val_accuracy did not improve from 0.99155
# Epoch 43/50
# 74/74 [==============================] - 32s 425ms/step - loss: 0.0653 - accuracy: 0.9889 - val_loss: 0.0613 - val_accuracy: 0.9865
#
# Epoch 00043: val_accuracy did not improve from 0.99155
# Epoch 44/50
# 74/74 [==============================] - 32s 426ms/step - loss: 0.0418 - accuracy: 0.9950 - val_loss: 0.0564 - val_accuracy: 0.9882
#
# Epoch 00044: val_accuracy did not improve from 0.99155
# Epoch 45/50
# 74/74 [==============================] - 32s 427ms/step - loss: 0.0511 - accuracy: 0.9937 - val_loss: 0.0522 - val_accuracy: 0.9882
#
# Epoch 00045: val_accuracy did not improve from 0.99155
# Epoch 46/50
# 74/74 [==============================] - 32s 425ms/step - loss: 0.0367 - accuracy: 0.9959 - val_loss: 0.0529 - val_accuracy: 0.9882
#
# Epoch 00046: val_accuracy did not improve from 0.99155
# Epoch 47/50
# 74/74 [==============================] - 32s 427ms/step - loss: 0.0412 - accuracy: 0.9950 - val_loss: 0.0489 - val_accuracy: 0.9882
#
# Epoch 00047: val_accuracy did not improve from 0.99155
# Epoch 48/50
# 74/74 [==============================] - 32s 428ms/step - loss: 0.0451 - accuracy: 0.9914 - val_loss: 0.0554 - val_accuracy: 0.9865
#
# Epoch 00048: val_accuracy did not improve from 0.99155
# Epoch 49/50
# 74/74 [==============================] - 32s 426ms/step - loss: 0.0438 - accuracy: 0.9899 - val_loss: 0.0540 - val_accuracy: 0.9865
#
# Epoch 00049: val_accuracy did not improve from 0.99155
# Epoch 50/50
# 74/74 [==============================] - 31s 425ms/step - loss: 0.0399 - accuracy: 0.9935 - val_loss: 0.0466 - val_accuracy: 0.9882
#
# Epoch 00050: val_accuracy did not improve from 0.99155
# {'burger': 0, 'not': 1}

# %%
K.clear_session()
model_best = load_model('/content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/trainedmodel_2class.hdf5',compile = False)

# %%
def predict_class(model, images, show = True):
  for img in images:
    img = image.load_img(img, target_size=(299, 299))
    img = image.img_to_array(img)                    
    img = np.expand_dims(img, axis=0)         
    img = preprocess_input(img)                                      

    pred = model.predict(img)
    index = np.argmax(pred)
    food_list.sort()
    pred_value = food_list[index]
    #print(pred)
    if show:
        plt.imshow(img[0])                           
        plt.axis('off')
        plt.title(pred_value)
        plt.show()

# %%
# Make a list of images and test the trained model
images = []
imagepath = root_position+'food-101/try/'
images.append(imagepath+'ramen.jpg')
images.append(imagepath+'pizza.jpg')
images.append(imagepath+'pizza2.jpg')
images.append(imagepath+'sushi.jpg')
images.append(imagepath+'sushi2.jpg')
images.append(imagepath+'sushi3.jpg')
images.append(imagepath+'sushi4.jpg')
predict_class(model_best, images, True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-12557a05fb30> in <module>()
#       1 # Make a list of images and test the trained model
#       2 images = []
# ----> 3 imagepath = root_position+'food-101/try/'
#       4 images.append(imagepath+'ramen.jpg')
#       5 images.append(imagepath+'pizza.jpg')
#
# NameError: name 'root_position' is not defined

# %%
def plot_accuracy(history,title):
    plt.title(title)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train_accuracy', 'validation_accuracy'], loc='best')
    plt.show()


def plot_loss(history,title):
    plt.title(title)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train_loss', 'validation_loss'], loc='best')
    plt.show()


plot_accuracy(history,'FOOD101-Inceptionv3')
plot_loss(history,'FOOD101-Inceptionv3')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-70841d810b30> in <module>()
#      19
#      20
# ---> 21 plot_accuracy(history,'FOOD101-Inceptionv3')
#      22 plot_loss(history,'FOOD101-Inceptionv3')
#
# NameError: name 'history' is not defined

# %%
def train_model_Next(n_classes,num_epochs, nb_train_samples,nb_validation_samples):
  K.clear_session()

  img_width, img_height = 299, 299
  train_data_dir = root_position+'foods-IG/sushi/train'
  validation_data_dir = root_position+'foods-IG/sushi/test'
  batch_size = 16
  bestmodel_path = '/content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/Newbestmodel_2class.hdf5'
  trainedmodel_path = '/content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/trainedmodel_2class.hdf5'
  history_path = '/content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/history_2.log'

  train_datagen = ImageDataGenerator(
      preprocessing_function=preprocess_input,
      shear_range=0.2,
      zoom_range=0.2,
      horizontal_flip=True)

  test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

  train_generator = train_datagen.flow_from_directory(
      train_data_dir,
      target_size=(img_height, img_width),
      batch_size=batch_size,
      class_mode='categorical')

  validation_generator = test_datagen.flow_from_directory(
      validation_data_dir,
      target_size=(img_height, img_width),
      batch_size=batch_size,
      class_mode='categorical')


  # inception = InceptionV3(weights='imagenet', include_top=False)
  # x = inception.output
  # x = GlobalAveragePooling2D()(x)
  # x = Dense(128,activation='relu')(x)
  # x = Dropout(0.2)(x)

  # predictions = Dense(n_classes,kernel_regularizer=regularizers.l2(0.005), activation='softmax')(x)

  model = load_model('/content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/bestmodel_2class.hdf5')
  model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])
  checkpoint = ModelCheckpoint(filepath=bestmodel_path, verbose=1, save_best_only=True, monitor='val_accuracy', mode='max')
  csv_logger = CSVLogger(history_path)

  history = model.fit_generator(train_generator,
                      steps_per_epoch = nb_train_samples // batch_size,
                      validation_data=validation_generator,
                      validation_steps=nb_validation_samples // batch_size,
                      epochs=num_epochs,
                      verbose=1,
                      callbacks=[csv_logger, checkpoint])

  # model.save(trainedmodel_path)
  class_map = train_generator.class_indices
  return history, class_map

# %%
# Train the model with data from 3 classes
n_classes = 2
epochs = 10
nb_train_samples = train_files
nb_validation_samples = test_files

history, class_map_3 = train_model_Next(n_classes,epochs, nb_train_samples,nb_validation_samples)
print(class_map_3)
# Out:
# Found 1149 images belonging to 2 classes.
# Found 930 images belonging to 2 classes.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/10
# 71/71 [==============================] - 1300s 18s/step - loss: 0.1782 - accuracy: 0.9437 - val_loss: 0.1480 - val_accuracy: 0.9547
#
# Epoch 00001: val_accuracy improved from -inf to 0.95474, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/Newbestmodel_2class.hdf5
# Epoch 2/10
# 71/71 [==============================] - 1218s 17s/step - loss: 0.1912 - accuracy: 0.9306 - val_loss: 0.1386 - val_accuracy: 0.9612
#
# Epoch 00002: val_accuracy improved from 0.95474 to 0.96121, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/Newbestmodel_2class.hdf5
# Epoch 3/10
# 71/71 [==============================] - 1225s 17s/step - loss: 0.1455 - accuracy: 0.9638 - val_loss: 0.1399 - val_accuracy: 0.9547
#
# Epoch 00003: val_accuracy did not improve from 0.96121
# Epoch 4/10
# 71/71 [==============================] - 1227s 17s/step - loss: 0.1357 - accuracy: 0.9663 - val_loss: 0.1282 - val_accuracy: 0.9612
#
# Epoch 00004: val_accuracy did not improve from 0.96121
# Epoch 5/10
# 71/71 [==============================] - 1224s 17s/step - loss: 0.1449 - accuracy: 0.9603 - val_loss: 0.1235 - val_accuracy: 0.9623
#
# Epoch 00005: val_accuracy improved from 0.96121 to 0.96228, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/foodsClassification/Newbestmodel_2class.hdf5
# Epoch 6/10
# 71/71 [==============================] - 1233s 17s/step - loss: 0.1114 - accuracy: 0.9702 - val_loss: 0.1283 - val_accuracy: 0.9591
#
# Epoch 00006: val_accuracy did not improve from 0.96228
# Epoch 7/10
# 71/71 [==============================] - 1236s 17s/step - loss: 0.1133 - accuracy: 0.9650 - val_loss: 0.1286 - val_accuracy: 0.9591
#
# Epoch 00007: val_accuracy did not improve from 0.96228
# Epoch 8/10
# 71/71 [==============================] - 1227s 17s/step - loss: 0.1099 - accuracy: 0.9656 - val_loss: 0.1198 - val_accuracy: 0.9623
#
# Epoch 00008: val_accuracy did not improve from 0.96228
# Epoch 9/10
# 71/71 [==============================] - 1235s 17s/step - loss: 0.1211 - accuracy: 0.9647 - val_loss: 0.1259 - val_accuracy: 0.9580
#
# Epoch 00009: val_accuracy did not improve from 0.96228
# Epoch 10/10
# 71/71 [==============================] - 1223s 17s/step - loss: 0.1007 - accuracy: 0.9781 - val_loss: 0.1178 - val_accuracy: 0.9623
#
# Epoch 00010: val_accuracy did not improve from 0.96228
# {'not': 0, 'sushi': 1}
